# %% [markdown]
# <a href="https://colab.research.google.com/github/giacomogreggio/computer-vision-project/blob/master/VGG_FCN8_with_variable_size.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Checking GPU Enabled

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# #Installing additional Libraries

# %%
import math
import numpy as np
import keras
import cv2

import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Input, MaxPool2D, ZeroPadding2D, Cropping2D, Softmax, Add, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.utils import Sequence

from IPython.display import clear_output
import matplotlib.pyplot as plt

# %% [markdown]
# # Downloading the Dataset

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
if "imgVOC" not in os.listdir("/content"):
  # !unzip "/content/drive/My Drive/VOC/img_VOC.zip"
if "SegmentationClassConvertedMin" not in os.listdir("/content"):
  # !unzip "/content/drive/My Drive/VOC/mask_VOC.zip"
# Out:
# Archive:  /content/drive/My Drive/VOC/img_VOC.zip
#    creating: imgVOC/
#   inflating: imgVOC/2007_000032.npy
#   inflating: imgVOC/2007_000033.npy
#   inflating: imgVOC/2007_000039.npy
#   inflating: imgVOC/2007_000042.npy
#   inflating: imgVOC/2007_000061.npy
#   inflating: imgVOC/2007_000063.npy
#   inflating: imgVOC/2007_000068.npy
#   inflating: imgVOC/2007_000121.npy
#   inflating: imgVOC/2007_000123.npy
#   inflating: imgVOC/2007_000129.npy
#   inflating: imgVOC/2007_000170.npy
#   inflating: imgVOC/2007_000175.npy
#   inflating: imgVOC/2007_000187.npy
#   inflating: imgVOC/2007_000241.npy
#   inflating: imgVOC/2007_000243.npy
#   inflating: imgVOC/2007_000250.npy
#   inflating: imgVOC/2007_000256.npy
#   inflating: imgVOC/2007_000323.npy
#   inflating: imgVOC/2007_000332.npy
#   inflating: imgVOC/2007_000333.npy
#   inflating: imgVOC/2007_000346.npy
#   inflating: imgVOC/2007_000363.npy
#   inflating: imgVOC/2007_000364.npy
#   inflating: imgVOC/2007_000392.npy
#   inflating: imgVOC/2007_000452.npy
#   inflating: imgVOC/2007_000464.npy
#   inflating: imgVOC/2007_000480.npy
#   inflating: imgVOC/2007_000491.npy
#   inflating: imgVOC/2007_000504.npy
#   inflating: imgVOC/2007_000515.npy
#   inflating: imgVOC/2007_000528.npy
#   inflating: imgVOC/2007_000529.npy
#   inflating: imgVOC/2007_000549.npy
#   inflating: imgVOC/2007_000559.npy
#   inflating: imgVOC/2007_000572.npy
#   inflating: imgVOC/2007_000584.npy
#   inflating: imgVOC/2007_000629.npy
#   inflating: imgVOC/2007_000636.npy
#   inflating: imgVOC/2007_000645.npy
#   inflating: imgVOC/2007_000648.npy
#   inflating: imgVOC/2007_000661.npy
#   inflating: imgVOC/2007_000663.npy
#   inflating: imgVOC/2007_000676.npy
#   inflating: imgVOC/2007_000713.npy
#   inflating: imgVOC/2007_000720.npy
#   inflating: imgVOC/2007_000727.npy
#   inflating: imgVOC/2007_000733.npy
#   inflating: imgVOC/2007_000738.npy
#   inflating: imgVOC/2007_000762.npy
#   inflating: imgVOC/2007_000768.npy
#   inflating: imgVOC/2007_000783.npy
#   inflating: imgVOC/2007_000793.npy
#   inflating: imgVOC/2007_000799.npy
#   inflating: imgVOC/2007_000804.npy
#   inflating: imgVOC/2007_000822.npy
#   inflating: imgVOC/2007_000830.npy
#   inflating: imgVOC/2007_000836.npy
#   inflating: imgVOC/2007_000837.npy
#   inflating: imgVOC/2007_000847.npy
#   inflating: imgVOC/2007_000862.npy
#   inflating: imgVOC/2007_000876.npy
#   inflating: imgVOC/2007_000904.npy
#   inflating: imgVOC/2007_000925.npy
#   inflating: imgVOC/2007_000999.npy
#   inflating: imgVOC/2007_001027.npy
#   inflating: imgVOC/2007_001073.npy
#   inflating: imgVOC/2007_001149.npy
#   inflating: imgVOC/2007_001154.npy
#   inflating: imgVOC/2007_001175.npy
#   inflating: imgVOC/2007_001185.npy
#   inflating: imgVOC/2007_001225.npy
#   inflating: imgVOC/2007_001239.npy
#   inflating: imgVOC/2007_001284.npy
#   inflating: imgVOC/2007_001288.npy
#   inflating: imgVOC/2007_001289.npy
#   inflating: imgVOC/2007_001299.npy
#   inflating: imgVOC/2007_001311.npy
#   inflating: imgVOC/2007_001321.npy
#   inflating: imgVOC/2007_001340.npy
#   inflating: imgVOC/2007_001377.npy
#   inflating: imgVOC/2007_001397.npy
#   inflating: imgVOC/2007_001408.npy
#   inflating: imgVOC/2007_001416.npy
#   inflating: imgVOC/2007_001420.npy
#   inflating: imgVOC/2007_001423.npy
#   inflating: imgVOC/2007_001430.npy
#   inflating: imgVOC/2007_001439.npy
#   inflating: imgVOC/2007_001457.npy
#   inflating: imgVOC/2007_001458.npy
#   inflating: imgVOC/2007_001487.npy
#   inflating: imgVOC/2007_001526.npy
#   inflating: imgVOC/2007_001568.npy
#   inflating: imgVOC/2007_001585.npy
#   inflating: imgVOC/2007_001586.npy
#   inflating: imgVOC/2007_001587.npy
#   inflating: imgVOC/2007_001594.npy
#   inflating: imgVOC/2007_001595.npy
#   inflating: imgVOC/2007_001602.npy
#   inflating: imgVOC/2007_001609.npy
#   inflating: imgVOC/2007_001630.npy
#   inflating: imgVOC/2007_001677.npy
#   inflating: imgVOC/2007_001678.npy
#   inflating: imgVOC/2007_001698.npy
#   inflating: imgVOC/2007_001704.npy
#   inflating: imgVOC/2007_001709.npy
#   inflating: imgVOC/2007_001717.npy
#   inflating: imgVOC/2007_001724.npy
#   inflating: imgVOC/2007_001733.npy
#   inflating: imgVOC/2007_001761.npy
#   inflating: imgVOC/2007_001763.npy
#   inflating: imgVOC/2007_001764.npy
#   inflating: imgVOC/2007_001774.npy
#   inflating: imgVOC/2007_001825.npy
#   inflating: imgVOC/2007_001834.npy
#   inflating: imgVOC/2007_001857.npy
#   inflating: imgVOC/2007_001872.npy
#   inflating: imgVOC/2007_001884.npy
#   inflating: imgVOC/2007_001901.npy
#   inflating: imgVOC/2007_001917.npy
#   inflating: imgVOC/2007_001955.npy
#   inflating: imgVOC/2007_001960.npy
#   inflating: imgVOC/2007_002024.npy
#   inflating: imgVOC/2007_002046.npy
#   inflating: imgVOC/2007_002055.npy
#   inflating: imgVOC/2007_002088.npy
#   inflating: imgVOC/2007_002094.npy
#   inflating: imgVOC/2007_002099.npy
#   inflating: imgVOC/2007_002105.npy
#   inflating: imgVOC/2007_002107.npy
#   inflating: imgVOC/2007_002119.npy
#   inflating: imgVOC/2007_002120.npy
#   inflating: imgVOC/2007_002132.npy
#   inflating: imgVOC/2007_002142.npy
#   inflating: imgVOC/2007_002198.npy
#   inflating: imgVOC/2007_002212.npy
#   inflating: imgVOC/2007_002216.npy
#   inflating: imgVOC/2007_002227.npy
#   inflating: imgVOC/2007_002234.npy
#   inflating: imgVOC/2007_002260.npy
#   inflating: imgVOC/2007_002266.npy
#   inflating: imgVOC/2007_002268.npy
#   inflating: imgVOC/2007_002273.npy
#   inflating: imgVOC/2007_002281.npy
#   inflating: imgVOC/2007_002284.npy
#   inflating: imgVOC/2007_002293.npy
#   inflating: imgVOC/2007_002361.npy
#   inflating: imgVOC/2007_002368.npy
#   inflating: imgVOC/2007_002370.npy
#   inflating: imgVOC/2007_002376.npy
#   inflating: imgVOC/2007_002378.npy
#   inflating: imgVOC/2007_002387.npy
#   inflating: imgVOC/2007_002400.npy
#   inflating: imgVOC/2007_002403.npy
#   inflating: imgVOC/2007_002412.npy
#   inflating: imgVOC/2007_002426.npy
#   inflating: imgVOC/2007_002427.npy
#   inflating: imgVOC/2007_002445.npy
#   inflating: imgVOC/2007_002462.npy
#   inflating: imgVOC/2007_002470.npy
#   inflating: imgVOC/2007_002488.npy
#   inflating: imgVOC/2007_002539.npy
#   inflating: imgVOC/2007_002545.npy
#   inflating: imgVOC/2007_002565.npy
#   inflating: imgVOC/2007_002597.npy
#   inflating: imgVOC/2007_002611.npy
#   inflating: imgVOC/2007_002618.npy
#   inflating: imgVOC/2007_002619.npy
#   inflating: imgVOC/2007_002624.npy
#   inflating: imgVOC/2007_002639.npy
#   inflating: imgVOC/2007_002643.npy
#   inflating: imgVOC/2007_002648.npy
#   inflating: imgVOC/2007_002668.npy
#   inflating: imgVOC/2007_002669.npy
#   inflating: imgVOC/2007_002719.npy
#   inflating: imgVOC/2007_002728.npy
#   inflating: imgVOC/2007_002760.npy
#   inflating: imgVOC/2007_002789.npy
#   inflating: imgVOC/2007_002823.npy
#   inflating: imgVOC/2007_002824.npy
#   inflating: imgVOC/2007_002845.npy
#   inflating: imgVOC/2007_002852.npy
#   inflating: imgVOC/2007_002895.npy
#   inflating: imgVOC/2007_002896.npy
#   inflating: imgVOC/2007_002903.npy
#   inflating: imgVOC/2007_002914.npy
#   inflating: imgVOC/2007_002953.npy
#   inflating: imgVOC/2007_002954.npy
#   inflating: imgVOC/2007_002967.npy
#   inflating: imgVOC/2007_003000.npy
#   inflating: imgVOC/2007_003011.npy
#   inflating: imgVOC/2007_003020.npy
#   inflating: imgVOC/2007_003022.npy
#   inflating: imgVOC/2007_003051.npy
#   inflating: imgVOC/2007_003088.npy
#   inflating: imgVOC/2007_003101.npy
#   inflating: imgVOC/2007_003106.npy
#   inflating: imgVOC/2007_003110.npy
#   inflating: imgVOC/2007_003118.npy
#   inflating: imgVOC/2007_003131.npy
#   inflating: imgVOC/2007_003134.npy
#   inflating: imgVOC/2007_003137.npy
#   inflating: imgVOC/2007_003143.npy
#   inflating: imgVOC/2007_003169.npy
#   inflating: imgVOC/2007_003178.npy
#   inflating: imgVOC/2007_003188.npy
#   inflating: imgVOC/2007_003189.npy
#   inflating: imgVOC/2007_003190.npy
#   inflating: imgVOC/2007_003191.npy
#   inflating: imgVOC/2007_003194.npy
#   inflating: imgVOC/2007_003195.npy
#   inflating: imgVOC/2007_003201.npy
#   inflating: imgVOC/2007_003205.npy
#   inflating: imgVOC/2007_003207.npy
#   inflating: imgVOC/2007_003251.npy
#   inflating: imgVOC/2007_003267.npy
#   inflating: imgVOC/2007_003286.npy
#   inflating: imgVOC/2007_003330.npy
#   inflating: imgVOC/2007_003349.npy
#   inflating: imgVOC/2007_003367.npy
#   inflating: imgVOC/2007_003373.npy
#   inflating: imgVOC/2007_003431.npy
#   inflating: imgVOC/2007_003451.npy
#   inflating: imgVOC/2007_003499.npy
#   inflating: imgVOC/2007_003503.npy
#   inflating: imgVOC/2007_003506.npy
#   inflating: imgVOC/2007_003525.npy
#   inflating: imgVOC/2007_003529.npy
#   inflating: imgVOC/2007_003530.npy
#   inflating: imgVOC/2007_003541.npy
#   inflating: imgVOC/2007_003565.npy
#   inflating: imgVOC/2007_003571.npy
#   inflating: imgVOC/2007_003580.npy
#   inflating: imgVOC/2007_003587.npy
#   inflating: imgVOC/2007_003593.npy
#   inflating: imgVOC/2007_003604.npy
#   inflating: imgVOC/2007_003611.npy
#   inflating: imgVOC/2007_003621.npy
#   inflating: imgVOC/2007_003668.npy
#   inflating: imgVOC/2007_003682.npy
#   inflating: imgVOC/2007_003711.npy
#   inflating: imgVOC/2007_003714.npy
#   inflating: imgVOC/2007_003715.npy
#   inflating: imgVOC/2007_003742.npy
#   inflating: imgVOC/2007_003778.npy
#   inflating: imgVOC/2007_003786.npy
#   inflating: imgVOC/2007_003788.npy
#   inflating: imgVOC/2007_003815.npy
#   inflating: imgVOC/2007_003841.npy
#   inflating: imgVOC/2007_003848.npy
#   inflating: imgVOC/2007_003861.npy
#   inflating: imgVOC/2007_003872.npy
#   inflating: imgVOC/2007_003876.npy
#   inflating: imgVOC/2007_003889.npy
#   inflating: imgVOC/2007_003910.npy
#   inflating: imgVOC/2007_003917.npy
#   inflating: imgVOC/2007_003957.npy
#   inflating: imgVOC/2007_003991.npy
#   inflating: imgVOC/2007_004003.npy
#   inflating: imgVOC/2007_004009.npy
#   inflating: imgVOC/2007_004033.npy
#   inflating: imgVOC/2007_004052.npy
#   inflating: imgVOC/2007_004065.npy
#   inflating: imgVOC/2007_004081.npy
#   inflating: imgVOC/2007_004112.npy
#   inflating: imgVOC/2007_004121.npy
#   inflating: imgVOC/2007_004143.npy
#   inflating: imgVOC/2007_004166.npy
#   inflating: imgVOC/2007_004189.npy
#   inflating: imgVOC/2007_004190.npy
#   inflating: imgVOC/2007_004193.npy
#   inflating: imgVOC/2007_004241.npy
#   inflating: imgVOC/2007_004275.npy
#   inflating: imgVOC/2007_004281.npy
#   inflating: imgVOC/2007_004289.npy
#   inflating: imgVOC/2007_004291.npy
#   inflating: imgVOC/2007_004328.npy
#   inflating: imgVOC/2007_004380.npy
#   inflating: imgVOC/2007_004392.npy
#   inflating: imgVOC/2007_004405.npy
#   inflating: imgVOC/2007_004423.npy
#   inflating: imgVOC/2007_004459.npy
#   inflating: imgVOC/2007_004468.npy
#   inflating: imgVOC/2007_004476.npy
#   inflating: imgVOC/2007_004481.npy
#   inflating: imgVOC/2007_004483.npy
#   inflating: imgVOC/2007_004500.npy
#   inflating: imgVOC/2007_004510.npy
#   inflating: imgVOC/2007_004537.npy
#   inflating: imgVOC/2007_004538.npy
#   inflating: imgVOC/2007_004558.npy
#   inflating: imgVOC/2007_004627.npy
#   inflating: imgVOC/2007_004644.npy
#   inflating: imgVOC/2007_004649.npy
#   inflating: imgVOC/2007_004663.npy
#   inflating: imgVOC/2007_004705.npy
#   inflating: imgVOC/2007_004707.npy
#   inflating: imgVOC/2007_004712.npy
#   inflating: imgVOC/2007_004722.npy
#   inflating: imgVOC/2007_004768.npy
#   inflating: imgVOC/2007_004769.npy
#   inflating: imgVOC/2007_004810.npy
#   inflating: imgVOC/2007_004830.npy
#   inflating: imgVOC/2007_004841.npy
#   inflating: imgVOC/2007_004856.npy
#   inflating: imgVOC/2007_004866.npy
#   inflating: imgVOC/2007_004902.npy
#   inflating: imgVOC/2007_004948.npy
#   inflating: imgVOC/2007_004951.npy
#   inflating: imgVOC/2007_004969.npy
#   inflating: imgVOC/2007_004988.npy
#   inflating: imgVOC/2007_004998.npy
#   inflating: imgVOC/2007_005043.npy
#   inflating: imgVOC/2007_005058.npy
#   inflating: imgVOC/2007_005064.npy
#   inflating: imgVOC/2007_005074.npy
#   inflating: imgVOC/2007_005086.npy
#   inflating: imgVOC/2007_005107.npy
#   inflating: imgVOC/2007_005114.npy
#   inflating: imgVOC/2007_005124.npy
#   inflating: imgVOC/2007_005130.npy
#   inflating: imgVOC/2007_005144.npy
#   inflating: imgVOC/2007_005149.npy
#   inflating: imgVOC/2007_005173.npy
#   inflating: imgVOC/2007_005210.npy
#   inflating: imgVOC/2007_005212.npy
#   inflating: imgVOC/2007_005227.npy
#   inflating: imgVOC/2007_005248.npy
#   inflating: imgVOC/2007_005262.npy
#   inflating: imgVOC/2007_005264.npy
#   inflating: imgVOC/2007_005266.npy
#   inflating: imgVOC/2007_005273.npy
#   inflating: imgVOC/2007_005281.npy
#   inflating: imgVOC/2007_005294.npy
#   inflating: imgVOC/2007_005296.npy
#   inflating: imgVOC/2007_005304.npy
#   inflating: imgVOC/2007_005314.npy
#   inflating: imgVOC/2007_005331.npy
#   inflating: imgVOC/2007_005354.npy
#   inflating: imgVOC/2007_005358.npy
#   inflating: imgVOC/2007_005360.npy
#   inflating: imgVOC/2007_005368.npy
#   inflating: imgVOC/2007_005428.npy
#   inflating: imgVOC/2007_005430.npy
#   inflating: imgVOC/2007_005460.npy
#   inflating: imgVOC/2007_005469.npy
#   inflating: imgVOC/2007_005509.npy
#   inflating: imgVOC/2007_005547.npy
#   inflating: imgVOC/2007_005600.npy
#   inflating: imgVOC/2007_005608.npy
#   inflating: imgVOC/2007_005626.npy
#   inflating: imgVOC/2007_005647.npy
#   inflating: imgVOC/2007_005688.npy
#   inflating: imgVOC/2007_005689.npy
#   inflating: imgVOC/2007_005696.npy
#   inflating: imgVOC/2007_005702.npy
#   inflating: imgVOC/2007_005705.npy
#   inflating: imgVOC/2007_005759.npy
#   inflating: imgVOC/2007_005790.npy
#   inflating: imgVOC/2007_005797.npy
#   inflating: imgVOC/2007_005803.npy
#   inflating: imgVOC/2007_005813.npy
#   inflating: imgVOC/2007_005828.npy
#   inflating: imgVOC/2007_005844.npy
#   inflating: imgVOC/2007_005845.npy
#   inflating: imgVOC/2007_005857.npy
#   inflating: imgVOC/2007_005859.npy
#   inflating: imgVOC/2007_005878.npy
#   inflating: imgVOC/2007_005902.npy
#   inflating: imgVOC/2007_005911.npy
#   inflating: imgVOC/2007_005915.npy
#   inflating: imgVOC/2007_005951.npy
#   inflating: imgVOC/2007_005978.npy
#   inflating: imgVOC/2007_005988.npy
#   inflating: imgVOC/2007_005989.npy
#   inflating: imgVOC/2007_006004.npy
#   inflating: imgVOC/2007_006028.npy
#   inflating: imgVOC/2007_006035.npy
#   inflating: imgVOC/2007_006046.npy
#   inflating: imgVOC/2007_006066.npy
#   inflating: imgVOC/2007_006076.npy
#   inflating: imgVOC/2007_006086.npy
#   inflating: imgVOC/2007_006117.npy
#   inflating: imgVOC/2007_006134.npy
#   inflating: imgVOC/2007_006136.npy
#   inflating: imgVOC/2007_006151.npy
#   inflating: imgVOC/2007_006171.npy
#   inflating: imgVOC/2007_006212.npy
#   inflating: imgVOC/2007_006232.npy
#   inflating: imgVOC/2007_006241.npy
#   inflating: imgVOC/2007_006254.npy
#   inflating: imgVOC/2007_006260.npy
#   inflating: imgVOC/2007_006277.npy
#   inflating: imgVOC/2007_006281.npy
#   inflating: imgVOC/2007_006303.npy
#   inflating: imgVOC/2007_006317.npy
#   inflating: imgVOC/2007_006348.npy
#   inflating: imgVOC/2007_006364.npy
#   inflating: imgVOC/2007_006373.npy
#   inflating: imgVOC/2007_006400.npy
#   inflating: imgVOC/2007_006409.npy
#   inflating: imgVOC/2007_006444.npy
#   inflating: imgVOC/2007_006445.npy
#   inflating: imgVOC/2007_006449.npy
#   inflating: imgVOC/2007_006477.npy
#   inflating: imgVOC/2007_006483.npy
#   inflating: imgVOC/2007_006490.npy
#   inflating: imgVOC/2007_006530.npy
#   inflating: imgVOC/2007_006549.npy
#   inflating: imgVOC/2007_006553.npy
#   inflating: imgVOC/2007_006560.npy
#   inflating: imgVOC/2007_006581.npy
#   inflating: imgVOC/2007_006585.npy
#   inflating: imgVOC/2007_006605.npy
#   inflating: imgVOC/2007_006615.npy
#   inflating: imgVOC/2007_006641.npy
#   inflating: imgVOC/2007_006647.npy
#   inflating: imgVOC/2007_006660.npy
#   inflating: imgVOC/2007_006661.npy
#   inflating: imgVOC/2007_006673.npy
#   inflating: imgVOC/2007_006678.npy
#   inflating: imgVOC/2007_006680.npy
#   inflating: imgVOC/2007_006698.npy
#   inflating: imgVOC/2007_006699.npy
#   inflating: imgVOC/2007_006704.npy
#   inflating: imgVOC/2007_006761.npy
#   inflating: imgVOC/2007_006802.npy
#   inflating: imgVOC/2007_006803.npy
#   inflating: imgVOC/2007_006832.npy
#   inflating: imgVOC/2007_006837.npy
#   inflating: imgVOC/2007_006841.npy
#   inflating: imgVOC/2007_006864.npy
#   inflating: imgVOC/2007_006865.npy
#   inflating: imgVOC/2007_006866.npy
#   inflating: imgVOC/2007_006899.npy
#   inflating: imgVOC/2007_006900.npy
#   inflating: imgVOC/2007_006944.npy
#   inflating: imgVOC/2007_006946.npy
#   inflating: imgVOC/2007_007003.npy
#   inflating: imgVOC/2007_007007.npy
#   inflating: imgVOC/2007_007021.npy
#   inflating: imgVOC/2007_007048.npy
#   inflating: imgVOC/2007_007084.npy
#   inflating: imgVOC/2007_007098.npy
#   inflating: imgVOC/2007_007109.npy
#   inflating: imgVOC/2007_007130.npy
#   inflating: imgVOC/2007_007154.npy
#   inflating: imgVOC/2007_007165.npy
#   inflating: imgVOC/2007_007168.npy
#   inflating: imgVOC/2007_007195.npy
#   inflating: imgVOC/2007_007196.npy
#   inflating: imgVOC/2007_007203.npy
#   inflating: imgVOC/2007_007211.npy
#   inflating: imgVOC/2007_007230.npy
#   inflating: imgVOC/2007_007235.npy
#   inflating: imgVOC/2007_007250.npy
#   inflating: imgVOC/2007_007341.npy
#   inflating: imgVOC/2007_007355.npy
#   inflating: imgVOC/2007_007387.npy
#   inflating: imgVOC/2007_007398.npy
#   inflating: imgVOC/2007_007414.npy
#   inflating: imgVOC/2007_007415.npy
#   inflating: imgVOC/2007_007417.npy
#   inflating: imgVOC/2007_007432.npy
#   inflating: imgVOC/2007_007447.npy
#   inflating: imgVOC/2007_007470.npy
#   inflating: imgVOC/2007_007477.npy
#   inflating: imgVOC/2007_007480.npy
#   inflating: imgVOC/2007_007481.npy
#   inflating: imgVOC/2007_007493.npy
#   inflating: imgVOC/2007_007498.npy
#   inflating: imgVOC/2007_007523.npy
#   inflating: imgVOC/2007_007524.npy
#   inflating: imgVOC/2007_007530.npy
#   inflating: imgVOC/2007_007534.npy
#   inflating: imgVOC/2007_007585.npy
#   inflating: imgVOC/2007_007591.npy
#   inflating: imgVOC/2007_007621.npy
#   inflating: imgVOC/2007_007624.npy
#   inflating: imgVOC/2007_007649.npy
#   inflating: imgVOC/2007_007651.npy
#   inflating: imgVOC/2007_007688.npy
#   inflating: imgVOC/2007_007698.npy
#   inflating: imgVOC/2007_007726.npy
#   inflating: imgVOC/2007_007748.npy
#   inflating: imgVOC/2007_007772.npy
#   inflating: imgVOC/2007_007773.npy
#   inflating: imgVOC/2007_007783.npy
#   inflating: imgVOC/2007_007795.npy
#   inflating: imgVOC/2007_007810.npy
#   inflating: imgVOC/2007_007815.npy
#   inflating: imgVOC/2007_007818.npy
#   inflating: imgVOC/2007_007836.npy
#   inflating: imgVOC/2007_007849.npy
#   inflating: imgVOC/2007_007878.npy
#   inflating: imgVOC/2007_007881.npy
#   inflating: imgVOC/2007_007890.npy
#   inflating: imgVOC/2007_007891.npy
#   inflating: imgVOC/2007_007902.npy
#   inflating: imgVOC/2007_007908.npy
#   inflating: imgVOC/2007_007930.npy
#   inflating: imgVOC/2007_007947.npy
#   inflating: imgVOC/2007_007948.npy
#   inflating: imgVOC/2007_007996.npy
#   inflating: imgVOC/2007_008043.npy
#   inflating: imgVOC/2007_008051.npy
#   inflating: imgVOC/2007_008072.npy
#   inflating: imgVOC/2007_008084.npy
#   inflating: imgVOC/2007_008085.npy
#   inflating: imgVOC/2007_008106.npy
#   inflating: imgVOC/2007_008110.npy
#   inflating: imgVOC/2007_008140.npy
#   inflating: imgVOC/2007_008142.npy
#   inflating: imgVOC/2007_008203.npy
#   inflating: imgVOC/2007_008204.npy
#   inflating: imgVOC/2007_008218.npy
#   inflating: imgVOC/2007_008219.npy
#   inflating: imgVOC/2007_008222.npy
#   inflating: imgVOC/2007_008256.npy
#   inflating: imgVOC/2007_008260.npy
#   inflating: imgVOC/2007_008307.npy
#   inflating: imgVOC/2007_008339.npy
#   inflating: imgVOC/2007_008374.npy
#   inflating: imgVOC/2007_008403.npy
#   inflating: imgVOC/2007_008407.npy
#   inflating: imgVOC/2007_008415.npy
#   inflating: imgVOC/2007_008430.npy
#   inflating: imgVOC/2007_008468.npy
#   inflating: imgVOC/2007_008526.npy
#   inflating: imgVOC/2007_008543.npy
#   inflating: imgVOC/2007_008547.npy
#   inflating: imgVOC/2007_008571.npy
#   inflating: imgVOC/2007_008575.npy
#   inflating: imgVOC/2007_008596.npy
#   inflating: imgVOC/2007_008645.npy
#   inflating: imgVOC/2007_008670.npy
#   inflating: imgVOC/2007_008708.npy
#   inflating: imgVOC/2007_008714.npy
#   inflating: imgVOC/2007_008722.npy
#   inflating: imgVOC/2007_008747.npy
#   inflating: imgVOC/2007_008764.npy
#   inflating: imgVOC/2007_008778.npy
#   inflating: imgVOC/2007_008801.npy
#   inflating: imgVOC/2007_008802.npy
#   inflating: imgVOC/2007_008815.npy
#   inflating: imgVOC/2007_008821.npy
#   inflating: imgVOC/2007_008897.npy
#   inflating: imgVOC/2007_008927.npy
#   inflating: imgVOC/2007_008932.npy
#   inflating: imgVOC/2007_008944.npy
#   inflating: imgVOC/2007_008945.npy
#   inflating: imgVOC/2007_008948.npy
#   inflating: imgVOC/2007_008964.npy
#   inflating: imgVOC/2007_008973.npy
#   inflating: imgVOC/2007_008980.npy
#   inflating: imgVOC/2007_008994.npy
#   inflating: imgVOC/2007_009015.npy
#   inflating: imgVOC/2007_009030.npy
#   inflating: imgVOC/2007_009052.npy
#   inflating: imgVOC/2007_009068.npy
#   inflating: imgVOC/2007_009082.npy
#   inflating: imgVOC/2007_009084.npy
#   inflating: imgVOC/2007_009088.npy
#   inflating: imgVOC/2007_009096.npy
#   inflating: imgVOC/2007_009139.npy
#   inflating: imgVOC/2007_009209.npy
#   inflating: imgVOC/2007_009216.npy
#   inflating: imgVOC/2007_009221.npy
#   inflating: imgVOC/2007_009245.npy
#   inflating: imgVOC/2007_009251.npy
#   inflating: imgVOC/2007_009252.npy
#   inflating: imgVOC/2007_009258.npy
#   inflating: imgVOC/2007_009295.npy
#   inflating: imgVOC/2007_009320.npy
#   inflating: imgVOC/2007_009322.npy
#   inflating: imgVOC/2007_009323.npy
#   inflating: imgVOC/2007_009327.npy
#   inflating: imgVOC/2007_009331.npy
#   inflating: imgVOC/2007_009346.npy
#   inflating: imgVOC/2007_009348.npy
#   inflating: imgVOC/2007_009392.npy
#   inflating: imgVOC/2007_009413.npy
#   inflating: imgVOC/2007_009419.npy
#   inflating: imgVOC/2007_009422.npy
#   inflating: imgVOC/2007_009435.npy
#   inflating: imgVOC/2007_009436.npy
#   inflating: imgVOC/2007_009446.npy
#   inflating: imgVOC/2007_009458.npy
#   inflating: imgVOC/2007_009464.npy
#   inflating: imgVOC/2007_009521.npy
#   inflating: imgVOC/2007_009527.npy
#   inflating: imgVOC/2007_009533.npy
#   inflating: imgVOC/2007_009550.npy
#   inflating: imgVOC/2007_009554.npy
#   inflating: imgVOC/2007_009562.npy
#   inflating: imgVOC/2007_009580.npy
#   inflating: imgVOC/2007_009592.npy
#   inflating: imgVOC/2007_009594.npy
#   inflating: imgVOC/2007_009597.npy
#   inflating: imgVOC/2007_009605.npy
#   inflating: imgVOC/2007_009607.npy
#   inflating: imgVOC/2007_009618.npy
#   inflating: imgVOC/2007_009630.npy
#   inflating: imgVOC/2007_009649.npy
#   inflating: imgVOC/2007_009654.npy
#   inflating: imgVOC/2007_009655.npy
#   inflating: imgVOC/2007_009665.npy
#   inflating: imgVOC/2007_009684.npy
#   inflating: imgVOC/2007_009687.npy
#   inflating: imgVOC/2007_009691.npy
#   inflating: imgVOC/2007_009706.npy
#   inflating: imgVOC/2007_009709.npy
#   inflating: imgVOC/2007_009724.npy
#   inflating: imgVOC/2007_009750.npy
#   inflating: imgVOC/2007_009756.npy
#   inflating: imgVOC/2007_009759.npy
#   inflating: imgVOC/2007_009764.npy
#   inflating: imgVOC/2007_009779.npy
#   inflating: imgVOC/2007_009788.npy
#   inflating: imgVOC/2007_009794.npy
#   inflating: imgVOC/2007_009807.npy
#   inflating: imgVOC/2007_009817.npy
#   inflating: imgVOC/2007_009832.npy
#   inflating: imgVOC/2007_009841.npy
#   inflating: imgVOC/2007_009889.npy
#   inflating: imgVOC/2007_009897.npy
#   inflating: imgVOC/2007_009899.npy
#   inflating: imgVOC/2007_009901.npy
#   inflating: imgVOC/2007_009911.npy
#   inflating: imgVOC/2007_009923.npy
#   inflating: imgVOC/2007_009938.npy
#   inflating: imgVOC/2007_009947.npy
#   inflating: imgVOC/2007_009950.npy
#   inflating: imgVOC/2008_000015.npy
#   inflating: imgVOC/2008_000016.npy
#   inflating: imgVOC/2008_000019.npy
#   inflating: imgVOC/2008_000033.npy
#   inflating: imgVOC/2008_000073.npy
#   inflating: imgVOC/2008_000074.npy
#   inflating: imgVOC/2008_000075.npy
#   inflating: imgVOC/2008_000080.npy
#   inflating: imgVOC/2008_000089.npy
#   inflating: imgVOC/2008_000103.npy
#   inflating: imgVOC/2008_000105.npy
#   inflating: imgVOC/2008_000107.npy
#   inflating: imgVOC/2008_000120.npy
#   inflating: imgVOC/2008_000123.npy
#   inflating: imgVOC/2008_000131.npy
#   inflating: imgVOC/2008_000144.npy
#   inflating: imgVOC/2008_000149.npy
#   inflating: imgVOC/2008_000182.npy
#   inflating: imgVOC/2008_000187.npy
#   inflating: imgVOC/2008_000188.npy
#   inflating: imgVOC/2008_000197.npy
#   inflating: imgVOC/2008_000207.npy
#   inflating: imgVOC/2008_000213.npy
#   inflating: imgVOC/2008_000215.npy
#   inflating: imgVOC/2008_000217.npy
#   inflating: imgVOC/2008_000223.npy
#   inflating: imgVOC/2008_000233.npy
#   inflating: imgVOC/2008_000235.npy
#   inflating: imgVOC/2008_000238.npy
#   inflating: imgVOC/2008_000239.npy
#   inflating: imgVOC/2008_000271.npy
#   inflating: imgVOC/2008_000273.npy
#   inflating: imgVOC/2008_000284.npy
#   inflating: imgVOC/2008_000287.npy
#   inflating: imgVOC/2008_000289.npy
#   inflating: imgVOC/2008_000290.npy
#   inflating: imgVOC/2008_000309.npy
#   inflating: imgVOC/2008_000316.npy
#   inflating: imgVOC/2008_000336.npy
#   inflating: imgVOC/2008_000345.npy
#   inflating: imgVOC/2008_000348.npy
#   inflating: imgVOC/2008_000361.npy
#   inflating: imgVOC/2008_000365.npy
#   inflating: imgVOC/2008_000391.npy
#   inflating: imgVOC/2008_000399.npy
#   inflating: imgVOC/2008_000401.npy
#   inflating: imgVOC/2008_000415.npy
#   inflating: imgVOC/2008_000422.npy
#   inflating: imgVOC/2008_000436.npy
#   inflating: imgVOC/2008_000464.npy
#   inflating: imgVOC/2008_000474.npy
#   inflating: imgVOC/2008_000491.npy
#   inflating: imgVOC/2008_000501.npy
#   inflating: imgVOC/2008_000505.npy
#   inflating: imgVOC/2008_000510.npy
#   inflating: imgVOC/2008_000515.npy
#   inflating: imgVOC/2008_000533.npy
#   inflating: imgVOC/2008_000540.npy
#   inflating: imgVOC/2008_000567.npy
#   inflating: imgVOC/2008_000573.npy
#   inflating: imgVOC/2008_000578.npy
#   inflating: imgVOC/2008_000584.npy
#   inflating: imgVOC/2008_000589.npy
#   inflating: imgVOC/2008_000595.npy
#   inflating: imgVOC/2008_000602.npy
#   inflating: imgVOC/2008_000626.npy
#   inflating: imgVOC/2008_000630.npy
#   inflating: imgVOC/2008_000645.npy
#   inflating: imgVOC/2008_000657.npy
#   inflating: imgVOC/2008_000661.npy
#   inflating: imgVOC/2008_000662.npy
#   inflating: imgVOC/2008_000666.npy
#   inflating: imgVOC/2008_000696.npy
#   inflating: imgVOC/2008_000700.npy
#   inflating: imgVOC/2008_000711.npy
#   inflating: imgVOC/2008_000716.npy
#   inflating: imgVOC/2008_000725.npy
#   inflating: imgVOC/2008_000731.npy
#   inflating: imgVOC/2008_000733.npy
#   inflating: imgVOC/2008_000760.npy
#   inflating: imgVOC/2008_000763.npy
#   inflating: imgVOC/2008_000764.npy
#   inflating: imgVOC/2008_000765.npy
#   inflating: imgVOC/2008_000778.npy
#   inflating: imgVOC/2008_000782.npy
#   inflating: imgVOC/2008_000785.npy
#   inflating: imgVOC/2008_000811.npy
#   inflating: imgVOC/2008_000832.npy
#   inflating: imgVOC/2008_000853.npy
#   inflating: imgVOC/2008_000860.npy
#   inflating: imgVOC/2008_000861.npy
#   inflating: imgVOC/2008_000911.npy
#   inflating: imgVOC/2008_000919.npy
#   inflating: imgVOC/2008_000923.npy
#   inflating: imgVOC/2008_000943.npy
#   inflating: imgVOC/2008_000992.npy
#   inflating: imgVOC/2008_001028.npy
#   inflating: imgVOC/2008_001030.npy
#   inflating: imgVOC/2008_001040.npy
#   inflating: imgVOC/2008_001056.npy
#   inflating: imgVOC/2008_001070.npy
#   inflating: imgVOC/2008_001074.npy
#   inflating: imgVOC/2008_001076.npy
#   inflating: imgVOC/2008_001078.npy
#   inflating: imgVOC/2008_001106.npy
#   inflating: imgVOC/2008_001118.npy
#   inflating: imgVOC/2008_001135.npy
#   inflating: imgVOC/2008_001137.npy
#   inflating: imgVOC/2008_001170.npy
#   inflating: imgVOC/2008_001188.npy
#   inflating: imgVOC/2008_001208.npy
#   inflating: imgVOC/2008_001215.npy
#   inflating: imgVOC/2008_001231.npy
#   inflating: imgVOC/2008_001235.npy
#   inflating: imgVOC/2008_001249.npy
#   inflating: imgVOC/2008_001260.npy
#   inflating: imgVOC/2008_001274.npy
#   inflating: imgVOC/2008_001308.npy
#   inflating: imgVOC/2008_001375.npy
#   inflating: imgVOC/2008_001379.npy
#   inflating: imgVOC/2008_001387.npy
#   inflating: imgVOC/2008_001399.npy
#   inflating: imgVOC/2008_001402.npy
#   inflating: imgVOC/2008_001404.npy
#   inflating: imgVOC/2008_001408.npy
#   inflating: imgVOC/2008_001413.npy
#   inflating: imgVOC/2008_001433.npy
#   inflating: imgVOC/2008_001439.npy
#   inflating: imgVOC/2008_001462.npy
#   inflating: imgVOC/2008_001478.npy
#   inflating: imgVOC/2008_001479.npy
#   inflating: imgVOC/2008_001498.npy
#   inflating: imgVOC/2008_001504.npy
#   inflating: imgVOC/2008_001510.npy
#   inflating: imgVOC/2008_001513.npy
#   inflating: imgVOC/2008_001514.npy
#   inflating: imgVOC/2008_001523.npy
#   inflating: imgVOC/2008_001531.npy
#   inflating: imgVOC/2008_001546.npy
#   inflating: imgVOC/2008_001547.npy
#   inflating: imgVOC/2008_001566.npy
#   inflating: imgVOC/2008_001580.npy
#   inflating: imgVOC/2008_001592.npy
#   inflating: imgVOC/2008_001601.npy
#   inflating: imgVOC/2008_001610.npy
#   inflating: imgVOC/2008_001632.npy
#   inflating: imgVOC/2008_001640.npy
#   inflating: imgVOC/2008_001682.npy
#   inflating: imgVOC/2008_001691.npy
#   inflating: imgVOC/2008_001715.npy
#   inflating: imgVOC/2008_001716.npy
#   inflating: imgVOC/2008_001719.npy
#   inflating: imgVOC/2008_001741.npy
#   inflating: imgVOC/2008_001761.npy
#   inflating: imgVOC/2008_001787.npy
#   inflating: imgVOC/2008_001821.npy
#   inflating: imgVOC/2008_001829.npy
#   inflating: imgVOC/2008_001874.npy
#   inflating: imgVOC/2008_001876.npy
#   inflating: imgVOC/2008_001882.npy
#   inflating: imgVOC/2008_001885.npy
#   inflating: imgVOC/2008_001896.npy
#   inflating: imgVOC/2008_001926.npy
#   inflating: imgVOC/2008_001966.npy
#   inflating: imgVOC/2008_001971.npy
#   inflating: imgVOC/2008_002043.npy
#   inflating: imgVOC/2008_002064.npy
#   inflating: imgVOC/2008_002066.npy
#   inflating: imgVOC/2008_002073.npy
#   inflating: imgVOC/2008_002080.npy
#   inflating: imgVOC/2008_002152.npy
#   inflating: imgVOC/2008_002160.npy
#   inflating: imgVOC/2008_002175.npy
#   inflating: imgVOC/2008_002182.npy
#   inflating: imgVOC/2008_002200.npy
#   inflating: imgVOC/2008_002205.npy
#   inflating: imgVOC/2008_002215.npy
#   inflating: imgVOC/2008_002218.npy
#   inflating: imgVOC/2008_002221.npy
#   inflating: imgVOC/2008_002239.npy
#   inflating: imgVOC/2008_002240.npy
#   inflating: imgVOC/2008_002247.npy
#   inflating: imgVOC/2008_002248.npy
#   inflating: imgVOC/2008_002255.npy
#   inflating: imgVOC/2008_002258.npy
#   inflating: imgVOC/2008_002269.npy
#   inflating: imgVOC/2008_002273.npy
#   inflating: imgVOC/2008_002288.npy
#   inflating: imgVOC/2008_002338.npy
#   inflating: imgVOC/2008_002358.npy
#   inflating: imgVOC/2008_002379.npy
#   inflating: imgVOC/2008_002383.npy
#   inflating: imgVOC/2008_002425.npy
#   inflating: imgVOC/2008_002464.npy
#   inflating: imgVOC/2008_002467.npy
#   inflating: imgVOC/2008_002473.npy
#   inflating: imgVOC/2008_002504.npy
#   inflating: imgVOC/2008_002521.npy
#   inflating: imgVOC/2008_002536.npy
#   inflating: imgVOC/2008_002551.npy
#   inflating: imgVOC/2008_002623.npy
#   inflating: imgVOC/2008_002681.npy
#   inflating: imgVOC/2008_002697.npy
#   inflating: imgVOC/2008_002704.npy
#   inflating: imgVOC/2008_002710.npy
#   inflating: imgVOC/2008_002719.npy
#   inflating: imgVOC/2008_002772.npy
#   inflating: imgVOC/2008_002775.npy

# %%
TRAIN_FILE_NAMES=open("/content/drive/My Drive/VOC/train.txt").read().split()
VAL_FILE_NAMES=open("/content/drive/My Drive/VOC/val.txt").read().split()

# %%
def open_image(name, path):
    with open(path + '/' + name+".npy", 'rb') as f:
        return np.load(f)

# %% [markdown]
# #Important Hyperparameters

# %%
IMAGE_SHAPE=(500,500,3)
N_CLASSES=22
L2_VALUE=5**-4

BATCH_SIZE = 20
BUFFER_SIZE = 1000
EPOCHS = 500
VAL_SUBSPLITS = 5

DATASET_PATH = "/content"
IMAGE_PATH = DATASET_PATH + '/imgVOC'
MASK_PATH = DATASET_PATH + '/SegmentationClassConvertedMin'

TRAIN_LENGTH = len(TRAIN_FILE_NAMES)
VALIDATION_STEPS = len(VAL_FILE_NAMES)//BATCH_SIZE//VAL_SUBSPLITS
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

# %% [markdown]
# # Taking a look at the dataset

# %%
def print_img(img):
    plt.figure(figsize=(14, 7))
    plt.subplot(1,1,1), plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)), plt.title('Lena'), plt.axis('off')
    
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']
    if (len(display_list)>1 and len(display_list[1].shape)==2):
      display_list[1] = np.expand_dims(display_list[1],axis=2)

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()
    
def create_mask(pred_mask):
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0]


def show_predictions(num=1):
    for i in range(num if num < len(example_images) else len(example_images)):  
        n = len(example_images)-i-1
        pred_mask = create_mask(model(np.expand_dims(example_images[i],axis=0)))
        display([example_images[n], example_masks[n], pred_mask])

# %%
number_of_examples = 10

example_images = []
example_masks = []
for i, img_id in enumerate(VAL_FILE_NAMES):
    example_images.append(open_image(img_id, IMAGE_PATH))
    example_masks.append(open_image(img_id, MASK_PATH))
    
    if i==number_of_examples:
        break

# %% [markdown]
# # Defining the models

# %%
class Crop(tf.keras.layers.Layer):
  def call(self, inputs):
    x1, x2 = inputs
    x1_shape = tf.shape(x1)
    x2_shape = tf.shape(x2)
    # offsets for the top left corner of the crop
    offsets = [0, (x1_shape[1] - x2_shape[1]) // 2, (x1_shape[2] - x2_shape[2]) // 2, 0]
    size = [-1, x2_shape[1], x2_shape[2], -1]
    x1_crop = tf.slice(x1, offsets, size)
    return x1_crop

# %% [markdown]
# ## Base Vgg Architecture

# %%
def create_base_vgg(trainable=True):
  tf.keras.backend.clear_session()
  #Defining Base VGG architecture
  input_layer = Input(shape=(None,None,3), name="input")
  #VGG-block1
  b1 = Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu", name="conv2d_b1_1")(input_layer)
  b1 = Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu", name="conv2d_b1_2")(b1)
  b1 = MaxPool2D(pool_size=(2,2),strides=(2,2), name="maxpool_b1")(b1)

  #VGG-block2
  b2 = Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu", name="conv2d_b2_1")(b1)
  b2 = Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu", name="conv2d_b2_2")(b2)
  b2 = MaxPool2D(pool_size=(2,2),strides=(2,2), name="maxpool_b2")(b2)

  #VGG-block3
  b3 = Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu", name="conv2d_b3_1")(b2)
  b3 = Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu", name="conv2d_b3_2")(b3)
  b3 = Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu", name="conv2d_b3_3")(b3)
  b3 = MaxPool2D(pool_size=(2,2),strides=(2,2), name="maxpool_b3")(b3)

  #VGG-block4
  b4 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu", name="conv2d_b4_1")(b3)
  b4 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu", name="conv2d_b4_2")(b4)
  b4 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu", name="conv2d_b4_3")(b4)
  b4 = MaxPool2D(pool_size=(2,2),strides=(2,2), name="maxpool_b4")(b4)

  #VGG-block5
  b5 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu", name="conv2d_b5_1")(b4)
  b5 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu", name="conv2d_b5_2")(b5)
  b5 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu", name="conv2d_b5_3")(b5)
  b5 = MaxPool2D(pool_size=(2,2),strides=(2,2), name="maxpool_b5")(b5)

  vgg_model = Model(input_layer, b5)
  vgg16= VGG16(weights="imagenet", include_top=False)
  vgg16.save_weights("./weights.h5")
  vgg_model.load_weights("./weights.h5")
  vgg_model.trainable=trainable

  return vgg_model

# %% [markdown]
# ## FCN-32

# %%
def create_fcn32(vgg_trainable=True, include_top=True):
  vgg_model=create_base_vgg(trainable=vgg_trainable)
  b5=vgg_model.layers[-1].output
  input_layer=vgg_model.layers[0].output
  fcn_32_block = Conv2D(4096, kernel_size=(7,7), activation='relu', padding="same", kernel_regularizer=l2(L2_VALUE), name="conv2d_fcn32_1")(b5)
  fcn_32_block = Dropout(0.5, name="dropout_fcn32_1")(fcn_32_block)
  fcn_32_block = Conv2D(4096, kernel_size=(1,1), activation='relu', padding="same", kernel_regularizer=l2(L2_VALUE), name="conv2d_fcn32_2")(fcn_32_block)
  fcn_32_block = Dropout(0.5, name="dropout_fcn32_2")(fcn_32_block)
  fcn_32_block = Conv2D(N_CLASSES, kernel_size=(1,1), padding="same", kernel_regularizer=l2(L2_VALUE), name="conv2d_fcn32_3")(fcn_32_block)
  if include_top:
    fcn_32_transpose = Conv2DTranspose(N_CLASSES, kernel_size=(64,64), strides=(32,32), kernel_regularizer=l2(L2_VALUE), use_bias=False, name="deconv_fcn32")(fcn_32_block)
    fcn_32_crop = Crop()([fcn_32_transpose, input_layer])
    fcn_32_softmax=Softmax(name="softmax_fcn32")(fcn_32_crop)
    return Model(input_layer, fcn_32_softmax)
  else:
    return Model(input_layer, fcn_32_block)

# %% [markdown]
# ##FCN-16

# %%
def create_fcn16(vgg_trainable=True, include_top=True):
  fcn_32=create_fcn32(vgg_trainable=vgg_trainable, include_top=False)
  input_layer=fcn_32.layers[0].output
  b4=fcn_32.get_layer("maxpool_b4").output
  fcn_32_block=fcn_32.layers[-1].output

  fcn_16_block_fcn32 = Conv2DTranspose(N_CLASSES, kernel_size=(4,4), padding="valid", strides=(2,2), kernel_regularizer=l2(L2_VALUE), use_bias=False, name="deconv_fcn16_1")(fcn_32_block)
  fcn_16_block = Conv2D(N_CLASSES, kernel_size=(1,1), activation="relu", kernel_regularizer=l2(L2_VALUE), padding="valid", name="conv2d_fcn16_1")(b4)

  fcn_16_block_fcn32 = Crop()([fcn_16_block_fcn32,fcn_16_block])

  fcn_16_block = Add(name="add_fcn16")([fcn_16_block_fcn32,fcn_16_block])

  if include_top:
    fcn_16_deconv = Conv2DTranspose(N_CLASSES, kernel_size=(32,32), strides=(16,16), kernel_regularizer=l2(L2_VALUE), use_bias=False, name="deconv_fcn16_2")(fcn_16_block)
    fcn_16_crop = Crop()([fcn_16_deconv,input_layer])
    fcn_16_softmax=Softmax(name="softmax_fcn16")(fcn_16_crop)
    return Model(input_layer, fcn_16_softmax)
  else:
    return Model(input_layer, fcn_16_block)

# %% [markdown]
# ##FCN-8

# %%
def create_fcn8(vgg_trainable=True, include_top=True):
  fcn_16=create_fcn16(vgg_trainable=vgg_trainable, include_top=False)
  input_layer=fcn_16.layers[0].output
  b3=fcn_16.get_layer("maxpool_b3").output
  fcn_16_block=fcn_16.layers[-1].output

  fcn_8_block_fcn16 = Conv2DTranspose(N_CLASSES, kernel_size=(4,4), padding="valid", strides=(2,2), kernel_regularizer=l2(L2_VALUE), use_bias=False, name="deconv_fnc8_1")(fcn_16_block)
  fcn_8_block = Conv2D(N_CLASSES, kernel_size=(1,1), activation="relu", kernel_regularizer=l2(L2_VALUE), padding="valid", name="conv2d_fcn8_1")(b3)
  
  fcn_8_block_fcn16 = Crop()([fcn_8_block_fcn16,fcn_8_block])
  
  fcn_8_block = Add(name="add_fcn8")([fcn_8_block_fcn16,fcn_8_block])

  if include_top:
    fcn_8_deconv = Conv2DTranspose(N_CLASSES, kernel_size=(16,16), strides=(8,8), kernel_regularizer=l2(L2_VALUE), use_bias=False, name="deconv_fnc8_2")(fcn_8_block)
    fcn_8_crop = Crop()([fcn_8_deconv,input_layer])
    fcn_8_softmax=Softmax(name="softmax_fcn8")(fcn_8_crop)
    return Model(input_layer, fcn_8_softmax)
  else:
    return Model(input_layer, fcn_8_block)

# %% [markdown]
# #Training the model

# %% [markdown]
# ##Defining Useful Callbacks

# %%
class DisplayCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    clear_output(wait=True)
    show_predictions()
    print ('\nSample Prediction after epoch {}\n'.format(epoch+1))

# %%
class print_lr(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        print("Current Learning rate : {}".format(self.model.optimizer.lr.numpy()))

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.1, patience=1, min_lr=10**-10)

# %%
csv_logger = tf.keras.callbacks.CSVLogger("/content/drive/My Drive/VOC/results.csv", separator=";", append=True)

# %%
callbacks=[
    keras.callbacks.EarlyStopping(patience=10),
    keras.callbacks.ModelCheckpoint("/content/drive/My Drive/VOC/best_model_weights.h5", save_best_only=True, verbose=1, save_only_weights=True),
    DisplayCallback(),
    csv_logger,
    reduce_lr, 
    print_lr(),
]

# %% [markdown]
# ##Defining custom mean_iou metric

# %%
class AdaptedMeanIoU(tf.keras.metrics.Metric):
  def __init__(self, name='mean_iou', n_classes=3,**kwargs):
    super(AdaptedMeanIoU, self).__init__(name=name, **kwargs)
    self.mean_iou=MeanIoU(n_classes)

  def update_state(self, y_true, y_pred, sample_weight=None):
    y_pred_converted=tf.argmax(y_pred,axis=-1)
    self.mean_iou.update_state(y_true,y_pred_converted)
  def result(self):
    return self.mean_iou.result()
  def reset_states(self):
    self.mean_iou.reset_states()

# %% [markdown]
# ## Data Generator

# %%
class DataGenerator(Sequence):
    def __init__(self, list_IDs, image_path, mask_path, to_fit=True, batch_size=32, shuffle=True):
        self.list_IDs = list_IDs
        self.image_path=image_path
        self.mask_path=mask_path
        self.to_fit = to_fit
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]

        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        X = self._generate_X(list_IDs_temp)

        if self.to_fit:
            y = self._generate_y(list_IDs_temp)
            return X, y
        else:
            return X

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def _generate_X(self, list_IDs_temp):
        X = []
        for i, ID in enumerate(list_IDs_temp):
            X.append(open_image(ID, self.image_path))
        return np.array(X)

    def _generate_y(self, list_IDs_temp):
        y = []
        for i, ID in enumerate(list_IDs_temp):
            y.append(open_image(ID, self.mask_path))
        return np.array(y)

# %% [markdown]
# ## Execute Training

# %% [markdown]
# ### Training FCN8

# %%
model=create_fcn8()
model.compile(optimizer=SGD(learning_rate=0.1, momentum=0.9, clipnorm=1), loss=SparseCategoricalCrossentropy(), metrics=[AdaptedMeanIoU(n_classes=N_CLASSES)])
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
generator_train = DataGenerator(TRAIN_FILE_NAMES, image_path=IMAGE_PATH, mask_path=MASK_PATH,
                          to_fit=True, batch_size=BATCH_SIZE,shuffle=True)

generator_val = DataGenerator(VAL_FILE_NAMES, image_path=IMAGE_PATH, mask_path=MASK_PATH,
                          to_fit=True, batch_size=BATCH_SIZE,shuffle=True)

model_history = model.fit(generator_train, epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          validation_steps=VALIDATION_STEPS,
                          callbacks=callbacks, validation_data=generator_val)

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(EPOCHS)

plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %% [markdown]
# # Make predictions

# %% [markdown]
# Let's make some predictions. In the interest of saving time, the number of epochs was kept small, but you may set this higher to achieve more accurate results.

# %%
show_predictions(10)
